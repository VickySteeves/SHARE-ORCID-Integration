# %% [markdown]
# This Python wrapper for the ORCID Public API v1.2 has been developed for the SHARE Curation Associates group working to integrate selected ORCID data into SHARE Notify.  It presupposes that Python 3, Jupyter Notebook, Requests and JSON dependencies have been met.
# Understand that only ORCID profiles in the public (production) server with visibility set to "public" can be captured by these queries.

# %%
Public_ORCID_API_BASE_URI = 'https://pub.orcid.org/v1.2/'

# %% [markdown]
# A known ORCID ID:

# %%
ORCID_ID = '0000-0002-7139-2625/'

# %% [markdown]
# Possible API types, not including Lucene, for public API v1.2:
#
#
# orcid-profile/ [returns entire ORCID]
# orcid-bio/ [returns names, biography, emails, external identifiers, keywords, researcher IDs]
# orcid-works/
# affiliations/ [returns educational history and employment]
# funding/

# %%
API_TYPE = 'orcid-bio/'
URI = Public_ORCID_API_BASE_URI + ORCID_ID + API_TYPE

# %% [markdown]
# Unparsed JSON results:

# %%
import requests
import json

payload={'Content-Type': 'application/orcid+json'}

r = requests.get(URI, json=payload)
print(r.url)
r.json()
# Out:
# https://pub.orcid.org/v1.2/0000-0002-7139-2625/orcid-bio/
# {'error-desc': None,
#  'message-version': '1.2',
#  'orcid-profile': {'client-type': None,
#   'group-type': None,
#   'orcid': None,
#   'orcid-activities': None,
#   'orcid-bio': {'biography': None,
#    'contact-details': {'address': {'country': {'value': 'US',
#       'visibility': 'PUBLIC'}},
#     'email': []},
#    'delegation': None,
#    'external-identifiers': {'external-identifier': [{'external-id-common-name': {'value': 'ResearcherID'},
#       'external-id-orcid': None,
#       'external-id-reference': {'value': 'O-1907-2013'},
#       'external-id-source': None,
#       'external-id-url': {'value': 'http://www.researcherid.com/rid/O-1907-2013'},
#       'orcid': None,
#       'source': {'source-client-id': None,
#        'source-date': {'value': 1387901349957},
#        'source-name': None,
#        'source-orcid': {'host': 'orcid.org',
#         'path': '0000-0001-7707-4137',
#         'uri': 'http://orcid.org/0000-0001-7707-4137',
#         'value': None}}},
#      {'external-id-common-name': {'value': 'ISNI'},
#       'external-id-orcid': None,
#       'external-id-reference': {'value': '0000000108836425'},
#       'external-id-source': None,
#       'external-id-url': {'value': 'http://isni.org/isni/0000000108836425'},
#       'orcid': None,
#       'source': {'source-client-id': None,
#        'source-date': {'value': 1392257577763},
#        'source-name': {'value': 'ISNI2ORCID search and link'},
#        'source-orcid': {'host': 'orcid.org',
#         'path': '0000-0003-0412-1857',
#         'uri': 'http://orcid.org/0000-0003-0412-1857',
#         'value': None}}}],
#     'visibility': 'PUBLIC'},
#    'keywords': {'keyword': [{'value': 'metadata, information modeling, natural language processing, Ancient Near East, Hebrew Scriptures'}],
#     'visibility': 'PUBLIC'},
#    'personal-details': {'credit-name': {'value': 'Steven W. Holloway',
#      'visibility': 'PUBLIC'},
#     'family-name': {'value': 'Holloway', 'visibility': None},
#     'given-names': {'value': 'Steven', 'visibility': None},
#     'other-names': {'other-name': [{'value': 'SW Holloway'},
#       {'value': 'Steven Winford Holloway'}],
#      'visibility': 'PUBLIC'}},
#    'researcher-urls': {'researcher-url': [{'url': {'value': 'http://isni.org/isni/0000000108836425'},
#       'url-name': {'value': 'ISNI'}},
#      {'url': {'value': 'http://lccn.loc.gov/no96037730'},
#       'url-name': {'value': 'LCNAF'}},
#      {'url': {'value': 'http://scholar.google.com/citations?user=9YUrD_8AAAAJ&hl=en'},
#       'url-name': {'value': 'Google Scholar Profile'}},
#      {'url': {'value': 'http://viaf.org/viaf/271237784/#Holloway,_Steven_W._(Steven_Winford),_1955-'},
#       'url-name': {'value': 'VIAF'}},
#      {'url': {'value': 'http://www.linkedin.com/pub/steven-holloway/22/46a/b86/'},
#       'url-name': {'value': 'LinkedIn'}},
#      {'url': {'value': 'http://www.researcherid.com/rid/O-1907-2013'},
#       'url-name': {'value': 'ResearcherID'}},
#      {'url': {'value': 'http://www.researchgate.net/profile/Steven_Holloway2'},
#       'url-name': {'value': 'ResearchGate'}},
#      {'url': {'value': 'http://www.worldcat.org/wcidentities/lccn-no96-37730'},
#       'url-name': {'value': 'WorldCat Identities'}},
#      {'url': {'value': 'https://jmu.academia.edu/StevenHolloway'},
#       'url-name': {'value': 'Academia.edu'}},
#      {'url': {'value': 'https://works.bepress.com/steven_holloway/'},
#       'url-name': {'value': 'SelectedWorks'}},
#      {'url': {'value': 'https://www.lib.jmu.edu/staffdir/bio.aspx?uid=293'},
#       'url-name': {'value': 'JMU Staff Directory'}}],
#     'visibility': 'PUBLIC'},
#    'scope': None},
#   'orcid-deprecated': None,
#   'orcid-history': {'claimed': {'value': True},
#    'completion-date': None,
#    'creation-method': 'WEBSITE',
#    'deactivation-date': None,
#    'last-modified-date': {'value': 1476968977866},
#    'source': None,
#    'submission-date': {'value': 1380035670780},
#    'verified-email': {'value': True},
#    'verified-primary-email': {'value': True},
#    'visibility': None},
#   'orcid-id': None,
#   'orcid-identifier': {'host': 'orcid.org',
#    'path': '0000-0002-7139-2625',
#    'uri': 'http://orcid.org/0000-0002-7139-2625',
#    'value': None},
#   'orcid-internal': None,
#   'orcid-preferences': {'locale': 'EN'},
#   'type': 'USER'},
#  'orcid-search-results': None}

# %% [markdown]
# Let's parse out the external (researcher) identifiers [limited by the ORCID v1.2 schema to two] and the other external researcher IDs [no max]:

# %%
r = requests.get(URI, json=payload).json()
print('External identifiers:')
results = r['orcid-profile']['orcid-bio']['external-identifiers']['external-identifier']
for i in results:
    print(i['external-id-url']['value'])
    

print ('Researcher identifiers:')
results2 = r['orcid-profile']['orcid-bio']['researcher-urls']['researcher-url']
for i in results2:
    print(i['url']['value'])
# Out:
# External identifiers:
# http://www.researcherid.com/rid/O-1907-2013
# http://isni.org/isni/0000000108836425
# Researcher identifiers:
# http://isni.org/isni/0000000108836425
# http://lccn.loc.gov/no96037730
# http://scholar.google.com/citations?user=9YUrD_8AAAAJ&hl=en
# http://viaf.org/viaf/271237784/#Holloway,_Steven_W._(Steven_Winford),_1955-
# http://www.linkedin.com/pub/steven-holloway/22/46a/b86/
# http://www.researcherid.com/rid/O-1907-2013
# http://www.researchgate.net/profile/Steven_Holloway2
# http://www.worldcat.org/wcidentities/lccn-no96-37730
# https://jmu.academia.edu/StevenHolloway
# https://works.bepress.com/steven_holloway/
# https://www.lib.jmu.edu/staffdir/bio.aspx?uid=293

# %% [markdown]
# A Lucene search uses the same ORCID API query types above, with the expected LUCENE syntax.  We'll create a modified URI, and write a query for ORCID holders with the family name "Holloway":

# %%
QUERY_TYPE = 'orcid-bio/'
URI = Public_ORCID_API + ORCID_ID + QUERY_TYPE

# %%
Q_URI = "https://pub.orcid.org/v1.2/search/" + API_TYPE + '?q='

# %% [markdown]
# The specific Lucene query:

# %%
LUCENE = 'family-name:Holloway'
L_QUERY = Q_URI + LUCENE + '&start=0&row=10'

# %%
The unparsed results:

# %%
r = requests.get(L_QUERY, json=payload)
print(r.url)
r.json()
# Out:
# https://pub.orcid.org/v1.2/search/orcid-bio/?q=family-name:Holloway&start=0&row=10
# {'error-desc': None,
#  'message-version': '1.2',
#  'orcid-profile': None,
#  'orcid-search-results': {'num-found': 101,
#   'orcid-search-result': [{'orcid-profile': {'client-type': None,
#      'group-type': None,
#      'orcid': None,
#      'orcid-activities': None,
#      'orcid-bio': {'biography': None,
#       'contact-details': None,
#       'delegation': None,
#       'external-identifiers': {'external-identifier': [{'external-id-common-name': {'value': 'ResearcherID'},
#          'external-id-orcid': None,
#          'external-id-reference': {'value': 'F-9911-2012'},
#          'external-id-source': None,
#          'external-id-url': {'value': 'http://www.researcherid.com/rid/F-9911-2012'},
#          'orcid': None,
#          'source': {'source-client-id': None,
#           'source-date': {'value': 1374076989961},
#           'source-name': None,
#           'source-orcid': {'host': 'orcid.org',
#            'path': '0000-0001-7707-4137',
#            'uri': 'http://orcid.org/0000-0001-7707-4137',
#            'value': None}}}],
#        'visibility': 'PUBLIC'},
#       'keywords': None,
#       'personal-details': {'credit-name': {'value': 'JS Holloway',
#         'visibility': 'PUBLIC'},
#        'family-name': {'value': 'Holloway', 'visibility': 'PUBLIC'},
#        'given-names': {'value': 'John', 'visibility': 'PUBLIC'},
#        'other-names': {'other-name': [{'value': 'J Holloway'}],
#         'visibility': 'PUBLIC'}},
#       'researcher-urls': None,
#       'scope': None},
#      'orcid-deprecated': None,
#      'orcid-history': None,
#      'orcid-id': None,
#      'orcid-identifier': {'host': 'orcid.org',
#       'path': '0000-0002-4585-9594',
#       'uri': 'http://orcid.org/0000-0002-4585-9594',
#       'value': None},
#      'orcid-internal': None,
#      'orcid-preferences': None,
#      'type': None},
#     'relevancy-score': {'value': 11.272912}},
#    {'orcid-profile': {'client-type': None,
#      'group-type': None,
#      'orcid': None,
#      'orcid-activities': None,
#      'orcid-bio': {'biography': None,
#       'contact-details': None,
#       'delegation': None,
#       'external-identifiers': None,
#       'keywords': None,
#       'personal-details': {'credit-name': None,
#        'family-name': {'value': 'Holloway', 'visibility': 'PUBLIC'},
#        'given-names': {'value': 'Paul', 'visibility': 'PUBLIC'},
#        'other-names': None},
#       'researcher-urls': None,
#       'scope': None},
#      'orcid-deprecated': None,
#      'orcid-history': None,
#      'orcid-id': None,
#      'orcid-identifier': {'host': 'orcid.org',
#       'path': '0000-0001-9270-6198',
#       'uri': 'http://orcid.org/0000-0001-9270-6198',
#       'value': None},
#      'orcid-internal': None,
#      'orcid-preferences': None,
#      'type': None},
#     'relevancy-score': {'value': 11.272912}},
#    {'orcid-profile': {'client-type': None,
#      'group-type': None,
#      'orcid': None,
#      'orcid-activities': None,
#      'orcid-bio': {'biography': None,
#       'contact-details': None,
#       'delegation': None,
#       'external-identifiers': None,
#       'keywords': None,
#       'personal-details': {'credit-name': None,
#        'family-name': {'value': 'Holloway', 'visibility': 'PUBLIC'},
#        'given-names': {'value': 'Timothy', 'visibility': 'PUBLIC'},
#        'other-names': None},
#       'researcher-urls': None,
#       'scope': None},
#      'orcid-deprecated': None,
#      'orcid-history': None,
#      'orcid-id': None,
#      'orcid-identifier': {'host': 'orcid.org',
#       'path': '0000-0002-3611-4726',
#       'uri': 'http://orcid.org/0000-0002-3611-4726',
#       'value': None},
#      'orcid-internal': None,
#      'orcid-preferences': None,
#      'type': None},
#     'relevancy-score': {'value': 11.272912}},
#    {'orcid-profile': {'client-type': None,
#      'group-type': None,
#      'orcid': None,
#      'orcid-activities': None,
#      'orcid-bio': {'biography': None,
#       'contact-details': None,
#       'delegation': None,
#       'external-identifiers': None,
#       'keywords': None,
#       'personal-details': {'credit-name': None,
#        'family-name': {'value': 'Holloway', 'visibility': 'PUBLIC'},
#        'given-names': {'value': 'Susan', 'visibility': 'PUBLIC'},
#        'other-names': None},
#       'researcher-urls': None,
#       'scope': None},
#      'orcid-deprecated': None,
#      'orcid-history': None,
#      'orcid-id': None,
#      'orcid-identifier': {'host': 'orcid.org',
#       'path': '0000-0001-9527-794X',
#       'uri': 'http://orcid.org/0000-0001-9527-794X',
#       'value': None},
#      'orcid-internal': None,
#      'orcid-preferences': None,
#      'type': None},
#     'relevancy-score': {'value': 11.272912}},
#    {'orcid-profile': {'client-type': None,
#      'group-type': None,
#      'orcid': None,
#      'orcid-activities': None,
#      'orcid-bio': {'biography': None,
#       'contact-details': None,
#       'delegation': None,
#       'external-identifiers': None,
#       'keywords': None,
#       'personal-details': {'credit-name': None,
#        'family-name': {'value': 'Holloway', 'visibility': 'PUBLIC'},
#        'given-names': {'value': 'Julia Bolton', 'visibility': 'PUBLIC'},
#        'other-names': None},
#       'researcher-urls': None,
#       'scope': None},
#      'orcid-deprecated': None,
#      'orcid-history': None,
#      'orcid-id': None,
#      'orcid-identifier': {'host': 'orcid.org',
#       'path': '0000-0003-0230-4991',
#       'uri': 'http://orcid.org/0000-0003-0230-4991',
#       'value': None},
#      'orcid-internal': None,
#      'orcid-preferences': None,
#      'type': None},
#     'relevancy-score': {'value': 11.272912}},
#    {'orcid-profile': {'client-type': None,
#      'group-type': None,
#      'orcid': None,
#      'orcid-activities': None,
#      'orcid-bio': {'biography': None,
#       'contact-details': None,
#       'delegation': None,
#       'external-identifiers': None,
#       'keywords': None,
#       'personal-details': {'credit-name': None,
#        'family-name': {'value': 'Holloway', 'visibility': 'PUBLIC'},
#        'given-names': {'value': 'Paul', 'visibility': 'PUBLIC'},
#        'other-names': None},
#       'researcher-urls': None,
#       'scope': None},
#      'orcid-deprecated': None,
#      'orcid-history': None,
#      'orcid-id': None,
#      'orcid-identifier': {'host': 'orcid.org',
#       'path': '0000-0002-1947-4885',
#       'uri': 'http://orcid.org/0000-0002-1947-4885',
#       'value': None},
#      'orcid-internal': None,
#      'orcid-preferences': None,
#      'type': None},
#     'relevancy-score': {'value': 11.272912}},
#    {'orcid-profile': {'client-type': None,
#      'group-type': None,
#      'orcid': None,
#      'orcid-activities': None,
#      'orcid-bio': {'biography': None,
#       'contact-details': None,
#       'delegation': None,
#       'external-identifiers': None,
#       'keywords': None,
#       'personal-details': {'credit-name': None,
#        'family-name': {'value': 'Holloway', 'visibility': 'PUBLIC'},
#        'given-names': {'value': 'Sarah', 'visibility': 'PUBLIC'},
#        'other-names': None},
#       'researcher-urls': None,
#       'scope': None},
#      'orcid-deprecated': None,
#      'orcid-history': None,
#      'orcid-id': None,
#      'orcid-identifier': {'host': 'orcid.org',
#       'path': '0000-0002-7662-6638',
#       'uri': 'http://orcid.org/0000-0002-7662-6638',
#       'value': None},
#      'orcid-internal': None,
#      'orcid-preferences': None,
#      'type': None},
#     'relevancy-score': {'value': 11.272912}},
#    {'orcid-profile': {'client-type': None,
#      'group-type': None,
#      'orcid': None,
#      'orcid-activities': None,
#      'orcid-bio': {'biography': None,
#       'contact-details': None,
#       'delegation': None,
#       'external-identifiers': {'external-identifier': [{'external-id-common-name': {'value': 'ResearcherID'},
#          'external-id-orcid': None,
#          'external-id-reference': {'value': 'O-3032-2013'},
#          'external-id-source': None,
#          'external-id-url': {'value': 'http://www.researcherid.com/rid/O-3032-2013'},
#          'orcid': None,
#          'source': {'source-client-id': None,
#           'source-date': {'value': 1388432757671},
#           'source-name': None,
#           'source-orcid': {'host': 'orcid.org',
#            'path': '0000-0001-7707-4137',
#            'uri': 'http://orcid.org/0000-0001-7707-4137',
#            'value': None}}}],
#        'visibility': 'PUBLIC'},
#       'keywords': None,
#       'personal-details': {'credit-name': {'value': 'Steven R Holloway',
#         'visibility': 'PUBLIC'},
#        'family-name': {'value': 'Holloway', 'visibility': 'PUBLIC'},
#        'given-names': {'value': 'Steven', 'visibility': 'PUBLIC'},
#        'other-names': {'other-name': [{'value': 'Steve Holloway, Steve R Holloway'}],
#         'visibility': 'PUBLIC'}},
#       'researcher-urls': None,
#       'scope': None},
#      'orcid-deprecated': None,
#      'orcid-history': None,
#      'orcid-id': None,
#      'orcid-identifier': {'host': 'orcid.org',
#       'path': '0000-0001-8900-5315',
#       'uri': 'http://orcid.org/0000-0001-8900-5315',
#       'value': None},
#      'orcid-internal': None,
#      'orcid-preferences': None,
#      'type': None},
#     'relevancy-score': {'value': 11.272912}},
#    {'orcid-profile': {'client-type': None,
#      'group-type': None,
#      'orcid': None,
#      'orcid-activities': None,
#      'orcid-bio': {'biography': None,
#       'contact-details': None,
#       'delegation': None,
#       'external-identifiers': None,
#       'keywords': None,
#       'personal-details': {'credit-name': None,
#        'family-name': {'value': 'Holloway', 'visibility': 'PUBLIC'},
#        'given-names': {'value': 'Topaz ', 'visibility': 'PUBLIC'},
#        'other-names': None},
#       'researcher-urls': None,
#       'scope': None},
#      'orcid-deprecated': None,
#      'orcid-history': None,
#      'orcid-id': None,
#      'orcid-identifier': {'host': 'orcid.org',
#       'path': '0000-0001-8085-1128',
#       'uri': 'http://orcid.org/0000-0001-8085-1128',
#       'value': None},
#      'orcid-internal': None,
#      'orcid-preferences': None,
#      'type': None},
#     'relevancy-score': {'value': 11.272912}},
#    {'orcid-profile': {'client-type': None,
#      'group-type': None,
#      'orcid': None,
#      'orcid-activities': None,
#      'orcid-bio': {'biography': None,
#       'contact-details': None,
#       'delegation': None,
#       'external-identifiers': None,
#       'keywords': None,
#       'personal-details': {'credit-name': None,
#        'family-name': {'value': 'Holloway', 'visibility': 'PUBLIC'},
#        'given-names': {'value': 'Caroline', 'visibility': 'PUBLIC'},
#        'other-names': None},
#       'researcher-urls': None,
#       'scope': None},
#      'orcid-deprecated': None,
#      'orcid-history': None,
#      'orcid-id': None,
#      'orcid-identifier': {'host': 'orcid.org',
#       'path': '0000-0003-3089-2006',
#       'uri': 'http://orcid.org/0000-0003-3089-2006',
#       'value': None},
#      'orcid-internal': None,
#      'orcid-preferences': None,
#      'type': None},
#     'relevancy-score': {'value': 11.272912}}]}}

# %% [markdown]
# Let's parse out the ORCID IDs for the Holloways in the production server.  The API throttles the number of hits displayed per query to 10:

# %%
r = requests.get(L_QUERY, json=payload).json()

hits = r['orcid-search-results']['num-found']
print('Total number of hits:', hits)


print ('ORCID-IDs for first ten Holloways:')
results = r['orcid-search-results']['orcid-search-result']

for i in results:
    print(i['orcid-profile']['orcid-identifier']['uri'])
# Out:
# Total number of hits: 101
# ORCID-IDs for first ten Holloways:
# http://orcid.org/0000-0002-4585-9594
# http://orcid.org/0000-0001-9270-6198
# http://orcid.org/0000-0002-3611-4726
# http://orcid.org/0000-0001-9527-794X
# http://orcid.org/0000-0003-0230-4991
# http://orcid.org/0000-0002-1947-4885
# http://orcid.org/0000-0002-7662-6638
# http://orcid.org/0000-0001-8900-5315
# http://orcid.org/0000-0001-8085-1128
# http://orcid.org/0000-0003-3089-2006

# %% [markdown]
# Wanna search for ORCID holders from your school?  The ORCID spec uses unique 4-digit RINGGOLD values for registered institutions -- easy, right?  The API does not directly support it -- go figure.  Your best bet is a LUCENE search with the RINGGOLD ID AND the school name, querying the orcid-bio section. So, for instance, in order to search for James Madison University ORCID holders, I use

# %%
L_QUERY = 'https://pub.orcid.org/v1.2/search/orcid-bio/?q=3745+AND+"James+Madison+University"&start=0&row=100'

r = requests.get(L_QUERY, json=payload)
print(r.url)
r.json()
# Out:
# https://pub.orcid.org/v1.2/search/orcid-bio/?q=3745+AND+%22James+Madison+University%22&start=0&row=100
# {'error-desc': None,
#  'message-version': '1.2',
#  'orcid-profile': None,
#  'orcid-search-results': {'num-found': 132,
#   'orcid-search-result': [{'orcid-profile': {'client-type': None,
#      'group-type': None,
#      'orcid': None,
#      'orcid-activities': None,
#      'orcid-bio': {'biography': None,
#       'contact-details': None,
#       'delegation': None,
#       'external-identifiers': None,
#       'keywords': None,
#       'personal-details': {'credit-name': None,
#        'family-name': {'value': 'Rogers', 'visibility': 'PUBLIC'},
#        'given-names': {'value': 'Elizabeth', 'visibility': 'PUBLIC'},
#        'other-names': None},
#       'researcher-urls': None,
#       'scope': None},
#      'orcid-deprecated': None,
#      'orcid-history': None,
#      'orcid-id': None,
#      'orcid-identifier': {'host': 'orcid.org',
#       'path': '0000-0003-3171-8579',
#       'uri': 'http://orcid.org/0000-0003-3171-8579',
#       'value': None},
#      'orcid-internal': None,
#      'orcid-preferences': None,
#      'type': None},
#     'relevancy-score': {'value': 1.1029446}},
#    {'orcid-profile': {'client-type': None,
#      'group-type': None,
#      'orcid': None,
#      'orcid-activities': None,
#      'orcid-bio': {'biography': None,
#       'contact-details': None,
#       'delegation': None,
#       'external-identifiers': None,
#       'keywords': None,
#       'personal-details': {'credit-name': None,
#        'family-name': {'value': 'Sandridge', 'visibility': 'PUBLIC'},
#        'given-names': {'value': 'Cindi', 'visibility': 'PUBLIC'},
#        'other-names': None},
#       'researcher-urls': None,
#       'scope': None},
#      'orcid-deprecated': None,
#      'orcid-history': None,
#      'orcid-id': None,
#      'orcid-identifier': {'host': 'orcid.org',
#       'path': '0000-0001-5631-9166',
#       'uri': 'http://orcid.org/0000-0001-5631-9166',
#       'value': None},
#      'orcid-internal': None,
#      'orcid-preferences': None,
#      'type': None},
#     'relevancy-score': {'value': 1.0398661}},
#    {'orcid-profile': {'client-type': None,
#      'group-type': None,
#      'orcid': None,
#      'orcid-activities': None,
#      'orcid-bio': {'biography': None,
#       'contact-details': None,
#       'delegation': None,
#       'external-identifiers': None,
#       'keywords': None,
#       'personal-details': {'credit-name': None,
#        'family-name': {'value': 'Nguyen', 'visibility': 'PUBLIC'},
#        'given-names': {'value': 'Andrew', 'visibility': 'PUBLIC'},
#        'other-names': None},
#       'researcher-urls': None,
#       'scope': None},
#      'orcid-deprecated': None,
#      'orcid-history': None,
#      'orcid-id': None,
#      'orcid-identifier': {'host': 'orcid.org',
#       'path': '0000-0001-9663-0178',
#       'uri': 'http://orcid.org/0000-0001-9663-0178',
#       'value': None},
#      'orcid-internal': None,
#      'orcid-preferences': None,
#      'type': None},
#     'relevancy-score': {'value': 1.0398661}},
#    {'orcid-profile': {'client-type': None,
#      'group-type': None,
#      'orcid': None,
#      'orcid-activities': None,
#      'orcid-bio': {'biography': None,
#       'contact-details': None,
#       'delegation': None,
#       'external-identifiers': None,
#       'keywords': None,
#       'personal-details': {'credit-name': None,
#        'family-name': {'value': 'Bachelder', 'visibility': 'PUBLIC'},
#        'given-names': {'value': 'Jessica', 'visibility': 'PUBLIC'},
#        'other-names': None},
#       'researcher-urls': None,
#       'scope': None},
#      'orcid-deprecated': None,
#      'orcid-history': None,
#      'orcid-id': None,
#      'orcid-identifier': {'host': 'orcid.org',
#       'path': '0000-0003-0040-1923',
#       'uri': 'http://orcid.org/0000-0003-0040-1923',
#       'value': None},
#      'orcid-internal': None,
#      'orcid-preferences': None,
#      'type': None},
#     'relevancy-score': {'value': 1.0398661}},
#    {'orcid-profile': {'client-type': None,
#      'group-type': None,
#      'orcid': None,
#      'orcid-activities': None,
#      'orcid-bio': {'biography': None,
#       'contact-details': None,
#       'delegation': None,
#       'external-identifiers': None,
#       'keywords': None,
#       'personal-details': {'credit-name': None,
#        'family-name': {'value': 'Weddle', 'visibility': 'PUBLIC'},
#        'given-names': {'value': 'Paula', 'visibility': 'PUBLIC'},
#        'other-names': None},
#       'researcher-urls': None,
#       'scope': None},
#      'orcid-deprecated': None,
#      'orcid-history': None,
#      'orcid-id': None,
#      'orcid-identifier': {'host': 'orcid.org',
#       'path': '0000-0002-1791-4541',
#       'uri': 'http://orcid.org/0000-0002-1791-4541',
#       'value': None},
#      'orcid-internal': None,
#      'orcid-preferences': None,
#      'type': None},
#     'relevancy-score': {'value': 1.0266848}},
#    {'orcid-profile': {'client-type': None,
#      'group-type': None,
#      'orcid': None,
#      'orcid-activities': None,
#      'orcid-bio': {'biography': None,
#       'contact-details': None,
#       'delegation': None,
#       'external-identifiers': None,
#       'keywords': None,
#       'personal-details': {'credit-name': None,
#        'family-name': {'value': 'Johnston', 'visibility': 'PUBLIC'},
#        'given-names': {'value': 'Mary', 'visibility': 'PUBLIC'},
#        'other-names': None},
#       'researcher-urls': None,
#       'scope': None},
#      'orcid-deprecated': None,
#      'orcid-history': None,
#      'orcid-id': None,
#      'orcid-identifier': {'host': 'orcid.org',
#       'path': '0000-0003-3556-4415',
#       'uri': 'http://orcid.org/0000-0003-3556-4415',
#       'value': None},
#      'orcid-internal': None,
#      'orcid-preferences': None,
#      'type': None},
#     'relevancy-score': {'value': 0.91912043}},
#    {'orcid-profile': {'client-type': None,
#      'group-type': None,
#      'orcid': None,
#      'orcid-activities': None,
#      'orcid-bio': {'biography': None,
#       'contact-details': None,
#       'delegation': None,
#       'external-identifiers': None,
#       'keywords': None,
#       'personal-details': {'credit-name': None,
#        'family-name': {'value': "O'Malley", 'visibility': 'PUBLIC'},
#        'given-names': {'value': 'John', 'visibility': 'PUBLIC'},
#        'other-names': None},
#       'researcher-urls': None,
#       'scope': None},
#      'orcid-deprecated': None,
#      'orcid-history': None,
#      'orcid-id': None,
#      'orcid-identifier': {'host': 'orcid.org',
#       'path': '0000-0003-3774-1702',
#       'uri': 'http://orcid.org/0000-0003-3774-1702',
#       'value': None},
#      'orcid-internal': None,
#      'orcid-preferences': None,
#      'type': None},
#     'relevancy-score': {'value': 0.91912043}},
#    {'orcid-profile': {'client-type': None,
#      'group-type': None,
#      'orcid': None,
#      'orcid-activities': None,
#      'orcid-bio': {'biography': None,
#       'contact-details': None,
#       'delegation': None,
#       'external-identifiers': None,
#       'keywords': None,
#       'personal-details': {'credit-name': None,
#        'family-name': {'value': 'Saville', 'visibility': 'PUBLIC'},
#        'given-names': {'value': 'Bryan', 'visibility': 'PUBLIC'},
#        'other-names': None},
#       'researcher-urls': None,
#       'scope': None},
#      'orcid-deprecated': None,
#      'orcid-history': None,
#      'orcid-id': None,
#      'orcid-identifier': {'host': 'orcid.org',
#       'path': '0000-0001-6815-5760',
#       'uri': 'http://orcid.org/0000-0001-6815-5760',
#       'value': None},
#      'orcid-internal': None,
#      'orcid-preferences': None,
#      'type': None},
#     'relevancy-score': {'value': 0.9098829}},
#    {'orcid-profile': {'client-type': None,
#      'group-type': None,
#      'orcid': None,
#      'orcid-activities': None,
#      'orcid-bio': {'biography': None,
#       'contact-details': None,
#       'delegation': None,
#       'external-identifiers': None,
#       'keywords': None,
#       'personal-details': {'credit-name': None,
#        'family-name': {'value': 'McKenna', 'visibility': 'PUBLIC'},
#        'given-names': {'value': 'Kristin', 'visibility': 'PUBLIC'},
#        'other-names': None},
#       'researcher-urls': None,
#       'scope': None},
#      'orcid-deprecated': None,
#      'orcid-history': None,
#      'orcid-id': None,
#      'orcid-identifier': {'host': 'orcid.org',
#       'path': '0000-0003-4606-0853',
#       'uri': 'http://orcid.org/0000-0003-4606-0853',
#       'value': None},
#      'orcid-internal': None,
#      'orcid-preferences': None,
#      'type': None},
#     'relevancy-score': {'value': 0.9098829}},
#    {'orcid-profile': {'client-type': None,
#      'group-type': None,
#      'orcid': None,
#      'orcid-activities': None,
#      'orcid-bio': {'biography': None,
#       'contact-details': None,
#       'delegation': None,
#       'external-identifiers': None,
#       'keywords': None,
#       'personal-details': {'credit-name': None,
#        'family-name': {'value': 'Barrella', 'visibility': 'PUBLIC'},
#        'given-names': {'value': 'Elise', 'visibility': 'PUBLIC'},
#        'other-names': None},
#       'researcher-urls': None,
#       'scope': None},
#      'orcid-deprecated': None,
#      'orcid-history': None,
#      'orcid-id': None,
#      'orcid-identifier': {'host': 'orcid.org',
#       'path': '0000-0003-0020-2035',
#       'uri': 'http://orcid.org/0000-0003-0020-2035',
#       'value': None},
#      'orcid-internal': None,
#      'orcid-preferences': None,
#      'type': None},
#     'relevancy-score': {'value': 0.9098829}}]}}

# %% [markdown]
# Finally, let's parse out some bibliographic information from a single ORCID profile.  Warned you --- it's MESSY.

# %%
PUB_URI = 'https://pub.orcid.org/v1.2/0000-0002-7139-2625/orcid-works/'

r = requests.get(PUB_URI, json=payload).json()

print ('Works:') 
results = r['orcid-profile']['orcid-activities']['orcid-works']['orcid-work']


for i in results:
    print('========')
    print('Publication titles:')
    print(i['work-title']['title']['value'])
    print('Work type:') 
    print(i['work-type'])

#work-citations may be any mix of BIBTEX and other formatted text, too 
#complicated for this simple python loop to handle, but you get the idea...

for i in results:
    print('========')
    print('Citation:')
    print(i['work-citation']['citation'])
    print('Citation type:')
    print(i['work-citation']['work-citation-type'])
    print('Work type:') 
    print(i['work-type'])
# Out:
# Works:
# ========
# Publication titles:
# Rainer Albertz, A History of Israelite Religion in the Old Testament Period, volume 1: From the Beginning to the End of the Monarchy
# Work type:
# BOOK_REVIEW
# ========
# Publication titles:
# Use of Assyriology in Chronological Apologetics in David’s Secret Demons
# Work type:
# JOURNAL_ARTICLE
# ========
# Publication titles:
# Giovanni Garbini, History and Ideology in Ancient Israel
# Work type:
# BOOK_REVIEW
# ========
# Publication titles:
# What Ship Goes There?
# Work type:
# BOOK_CHAPTER
# ========
# Publication titles:
# William Robertson Smith, Lectures on the Religion of the Semites: Second and Third Series
# Work type:
# BOOK_REVIEW
# ========
# Publication titles:
# Marvin A. Sweeney, King Josiah of Judah: The Lost Messiah of Israel
# Work type:
# BOOK_REVIEW
# ========
# Publication titles:
# Eckart Otto, Das Deuteronomium: Politische Theologie und Rechtsreform in Juda und Assyrien
# Work type:
# BOOK_REVIEW
# ========
# Publication titles:
# George E. Mendenhall and Gary A. Herion, Ancient Israel’s Faith and History: An Introduction to the Bible in Context
# Work type:
# BOOK_REVIEW
# ========
# Publication titles:
# The Masculinity of Male Angels on the Make: Genesis 6:1-4 in Early Nineteenth Century Gothic Imagination
# Work type:
# BOOK_CHAPTER
# ========
# Publication titles:
# Nineveh as Meme in Persian Period Yehud
# Work type:
# BOOK_CHAPTER
# ========
# Publication titles:
# Expansion of the Historical Context of the Hebrew Bible / Old Testament
# Work type:
# BOOK_CHAPTER
# ========
# Publication titles:
# 'The Past Is Never Dead. It’s Not Even Past': The Challenge of Data Provenance in the e-Humanities
# Work type:
# CONFERENCE_POSTER
# ========
# Publication titles:
# J. Gary Millar, Now Choose Life: Theology and Ethics in Deuteronomy
# Work type:
# BOOK_REVIEW
# ========
# Publication titles:
# Assur is King of Persia: Illustrations of the Book of Esther in Some Nineteenth-Century Sources
# Work type:
# JOURNAL_ARTICLE
# ========
# Publication titles:
# Assyriology and Biblical Studies
# Work type:
# ENCYCLOPEDIA_ENTRY
# ========
# Publication titles:
# Assyriology and Biblical Studies
# Work type:
# JOURNAL_ARTICLE
# ========
# Publication titles:
# In the Wake of Tikva Frymer-Kensky
# Work type:
# EDITED_BOOK
# ========
# Publication titles:
# Imagining the Unspeakable Genesis 6:1-4 in the Nineteenth Century
# Work type:
# JOURNAL_ARTICLE
# ========
# Publication titles:
# Introduction
# Work type:
# BOOK_CHAPTER
# ========
# Publication titles:
# Orientalism, Assyriology and the Bible
# Work type:
# EDITED_BOOK
# ========
# Publication titles:
# The Smithsonian Institution’s Religious Ceremonial Objects and Biblical Antiquities Exhibits at the World's Columbian Exposition (Chicago, 1893) and the Cotton States and International Exposition (Atlanta, 1895)
# Work type:
# BOOK_CHAPTER
# ========
# Publication titles:
# God Save Our Gracious King: Sennacherib, the Toast of Victorian England
# Work type:
# JOURNAL_ARTICLE
# ========
# Publication titles:
# Smart Mobs, Bad Crowds, Godly People and Dead Priests: Crowd Symbols in the Josianic Narrative and Some Mesopotamian Parallels
# Work type:
# JOURNAL_ARTICLE
# ========
# Publication titles:
# Austin’s Asiatic Antiquities: The First Cuneiform Inscriptions Published in America
# Work type:
# CONFERENCE_PAPER
# ========
# Publication titles:
# A ‘New’ Kutir-Nahhunte II Text
# Work type:
# JOURNAL_ARTICLE
# ========
# Publication titles:
# Nineveh Sails for the New World: Assyria Envisioned by Nineteenth-Century America
# Work type:
# JOURNAL_ARTICLE
# ========
# Publication titles:
# Aššur Is King! Aššur Is King!
# Work type:
# BOOK
# ========
# Publication titles:
# The Quest for Sargon, Pul, and Tiglath-Pileser in the 19th Century
# Work type:
# BOOK_CHAPTER
# ========
# Publication titles:
# Biblical Assyria and Other Anxieties in the British Empire
# Work type:
# JOURNAL_ARTICLE
# ========
# Publication titles:
# Mad to See the Monuments
# Work type:
# MAGAZINE_ARTICLE
# ========
# Publication titles:
# The giškakki Aššur and Neo-Assyrian Loyalty Oaths
# Work type:
# BOOK_CHAPTER
# ========
# Publication titles:
# Cutha
# Work type:
# DICTIONARY_ENTRY
# ========
# Publication titles:
# Haran
# Work type:
# DICTIONARY_ENTRY
# ========
# Publication titles:
# Moon
# Work type:
# ENCYCLOPEDIA_ENTRY
# ========
# Publication titles:
# New Moon
# Work type:
# ENCYCLOPEDIA_ENTRY
# ========
# Publication titles:
# Willett, Herbert Lockwood (5 May 1864-28 Mar. 1944)
# Work type:
# ENCYCLOPEDIA_ENTRY
# ========
# Publication titles:
# KTU 1.162 and the Offering of a Shield
# Work type:
# JOURNAL_ARTICLE
# ========
# Publication titles:
# Sargon II and His Redactors Repair Eanna of Uruk
# Work type:
# JOURNAL_ARTICLE
# ========
# Publication titles:
# The Invention of Ancient Israel: the Silencing of Palestinian History
# Work type:
# BOOK_REVIEW
# ========
# Publication titles:
# The Shape of Utnapishtim’s Ark
# Work type:
# JOURNAL_ARTICLE
# ========
# Publication titles:
# Antiochian Temporal Interpolations in 2 Kgs 6,24-7,20
# Work type:
# JOURNAL_ARTICLE
# ========
# Publication titles:
# Assyria and Babylonia in the Tenth Century BCE
# Work type:
# BOOK_CHAPTER
# ========
# Publication titles:
# Book Review Biblical Israel: State and People Benjamin Mazar and Shmuel Ahituv; In Search of 'Ancient Israel' Philip R. Davies; Prologue to History: The Yahwist as Historian in Genesis John van Seters
# Work type:
# JOURNAL_ARTICLE
# ========
# Publication titles:
# New Wine in Old Kings
# Work type:
# JOURNAL_ARTICLE
# ========
# Publication titles:
# Book Review:The Reforming Kings: Cults and Society in First Temple Judah Richard Harlin Lowery
# Work type:
# JOURNAL_ARTICLE
# ========
# Publication titles:
# Porch Lights in Neo-Assyrian Temples
# Work type:
# JOURNAL_ARTICLE
# ========
# Publication titles:
# Book Review:Som-Fasten: Kollektive Trauer um den verborgenen Gott im Alten Testament Thomas Podella
# Work type:
# JOURNAL_ARTICLE
# ========
# Publication titles:
# Harran
# Work type:
# BOOK_CHAPTER
# ========
# Publication titles:
# The Pitcher is Broken
# Work type:
# EDITED_BOOK
# ========
# Publication titles:
# Book Review Heilsgeschichte as a Model for Biblical Theology: The Debate concerning the Uniqueness and Significance of Israel's Worldview Robert Gnuse
# Work type:
# JOURNAL_ARTICLE
# ========
# Publication titles:
# Kings, Book of 1–2
# Work type:
# ENCYCLOPEDIA_ENTRY
# ========
# Publication titles:
# The Case for Assyrian Religious Influence in Israel and Judah:
# Work type:
# DISSERTATION
# ========
# Publication titles:
# <i>Secrets of the Times: Myth and History in Biblical Chronology</i> (review)
# Work type:
# JOURNAL_ARTICLE
# ========
# Publication titles:
# Distaff, Crutch or Chain Gang: The Curse of the House of Joab in 2 Samuel III 29
# Work type:
# JOURNAL_ARTICLE
# ========
# Publication titles:
# What Ship Goes There: The Flood Narratives in the Gilgamesh Epic and Genesis Considered in Light of Ancient Near Eastern Temple Ideology
# Work type:
# JOURNAL_ARTICLE
# ========
# Citation:
# Rainer Albertz, A History of Israelite Religion in the Old Testament Period, volume 1: From the Beginning to the End of the Monarchy, Journal of Near Eastern Studies 57 (1998): 224-27.
# Citation type:
# FORMATTED_CHICAGO
# Work type:
# BOOK_REVIEW
# ========
# Citation:
# “Use of Assyriology in Chronological Apologetics in David’s Secret Demons,” Scandinavian Journal for the Old Testament 17 (2003): 245-67.
# Citation type:
# FORMATTED_CHICAGO
# Work type:
# JOURNAL_ARTICLE
# ========
# Citation:
# Giovanni Garbini, History & Ideology in Ancient Israel, Journal of Religion 70 (1990): 245-46.
# Citation type:
# FORMATTED_CHICAGO
# Work type:
# BOOK_REVIEW
# ========
# Citation:
# “What Ship Goes There? The Flood Narratives in the Gilgamesh Epic and Genesis Considered in the Light of Ancient Near Eastern Temple Ideology,” in L. Michael Morales (ed.), Cult and Cosmos: Tilting Toward a Temple-Centered Theology (Biblical Tools and Studies, 18; Leuven: Peeters, 2014), 183-208 [reprint].
# Citation type:
# FORMATTED_UNSPECIFIED
# Work type:
# BOOK_CHAPTER
# ========
# Citation:
# @article{Holloway_2000, title={              Book Review              Lectures on the Religion of the Semites: Second and Third Series              William Robertson Smith and John Day            }, volume={59}, url={http://dx.doi.org/10.1086/468814}, DOI={10.1086/468814}, number={2}, journal={Journal of Near Eastern Studies}, publisher={The University of Chicago Press}, author={Holloway, Steven W.}, year={2000}, month={Apr}, pages={137}}
# Citation type:
# BIBTEX
# Work type:
# BOOK_REVIEW
# ========
# Citation:
# @article{Holloway_2007, title={:King Josiah of Judah: The Lost Messiah of Israel}, volume={66}, url={http://dx.doi.org/10.1086/524166}, DOI={10.1086/524166}, number={4}, journal={Journal of Near Eastern Studies}, publisher={The University of Chicago Press}, author={Holloway, Steven W.}, year={2007}, month={Oct}, pages={304-306}}
# Citation type:
# BIBTEX
# Work type:
# BOOK_REVIEW
# ========
# Citation:
# @article{Holloway_2007, title={:Das Deuteronomium: Politische Theologie und Rechtsreform in Juda und Assyrien}, volume={66}, url={http://dx.doi.org/10.1086/521757}, DOI={10.1086/521757}, number={3}, journal={Journal of Near Eastern Studies}, publisher={The University of Chicago Press}, author={Holloway, Steven W.}, year={2007}, month={Jul}, pages={205-208}}
# Citation type:
# BIBTEX
# Work type:
# BOOK_REVIEW
# ========
# Citation:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-90-8f57116cefd1> in <module>()
#      24     print('========')
#      25     print('Citation:')
# ---> 26     print(i['work-citation']['citation'])
#      27     print('Citation type:')
#      28     print(i['work-citation']['work-citation-type'])
#
# TypeError: 'NoneType' object is not subscriptable

# %% [markdown]
# The ORCID Sandbox API uses  ORCID schema v2.0_rc2, substantially more granular than the current public API
# schema. v2.0_rc2 supports direct querying of these elements of the ORCID profile:
# activities, address, education, email, employment, external-identifiers, funding, keywords,
# researcher-urls, person, personal-details.  You must also supply credentials for OAUTH2 authentication.

# %%
SANDBOX_ORCID_API_BASE_URI = 'https://api.sandbox.orcid.org/v2.0_rc2/'

SANDBOX_ORCID_ID = '0000-0002-9323-699X/'

# %% [markdown]
# Possible sandbox API types, not including Lucene:
#
# activities/
# address/
# education/
# email/
# employment/
# external-identifiers/
# funding/
# keywords/
# researcher-urls/
# person/
# personal-details/
# other-names/

# %%
SANDBOX_API_TYPE = 'funding/'
S_URI = SANDBOX_ORCID_API_BASE_URI + SANDBOX_ORCID_ID + SANDBOX_API_TYPE

# %% [markdown]
# Guys, if you can get requests_oauthlib to function with ORCID sandbox authentication, more power to you.  I have no problem using the API sandbox with cURL and my long-lasting token:
#
# curl -H "Accept: application/orcid+json" -H 'Authorization: Bearer [YOUR_LONG_LASTING_TOKEN]' 'https://api.sandbox.orcid.org/v2.0_rc2/0000-0002-9323-699X/activities/'

# %% [markdown]
# ORCID developers may use the v2.0_rc2 schema at their discretion:

# %%
URL = 'https://pub.orcid.org/v2.0_rc2/0000-0003-0902-4386/activities'

r = requests.get(URL, json=payload)
print(r.url)
r.json()
# Out:
# https://pub.orcid.org/v2.0_rc2/0000-0003-0902-4386/activities
# {'educations': {'education-summary': [{'created-date': {'value': 1435248072718},
#     'department-name': 'Computer Science',
#     'end-date': None,
#     'last-modified-date': {'value': 1442323001905},
#     'organization': {'address': {'city': 'Milton Keynes',
#       'country': 'GB',
#       'region': 'Milton Keynes'},
#      'disambiguated-organization': {'disambiguated-organization-identifier': '5488',
#       'disambiguation-source': 'RINGGOLD'},
#      'name': 'Open University'},
#     'path': '/0000-0003-0902-4386/education/990546',
#     'put-code': 990546,
#     'role-title': '1st class with honours',
#     'source': {'source-client-id': None,
#      'source-name': {'value': 'Tom Demeranville'},
#      'source-orcid': {'host': 'orcid.org',
#       'path': '0000-0003-0902-4386',
#       'uri': 'http://orcid.org/0000-0003-0902-4386'}},
#     'start-date': None,
#     'visibility': 'PUBLIC'}],
#   'last-modified-date': {'value': 1442323001905}},
#  'employments': {'employment-summary': [{'created-date': {'value': 1435247817057},
#     'department-name': 'Project Thor',
#     'end-date': None,
#     'last-modified-date': {'value': 1442323037800},
#     'organization': {'address': {'city': 'Bath',
#       'country': 'GB',
#       'region': None},
#      'disambiguated-organization': None,
#      'name': 'ORCID EU'},
#     'path': '/0000-0003-0902-4386/employment/990530',
#     'put-code': 990530,
#     'role-title': 'Senior Technical Officer',
#     'source': {'source-client-id': None,
#      'source-name': {'value': 'Tom Demeranville'},
#      'source-orcid': {'host': 'orcid.org',
#       'path': '0000-0003-0902-4386',
#       'uri': 'http://orcid.org/0000-0003-0902-4386'}},
#     'start-date': {'day': None,
#      'month': {'value': '06'},
#      'year': {'value': '2015'}},
#     'visibility': 'PUBLIC'},
#    {'created-date': {'value': 1435247976562},
#     'department-name': 'Athens',
#     'end-date': {'day': None,
#      'month': {'value': '02'},
#      'year': {'value': '2013'}},
#     'last-modified-date': {'value': 1435248184090},
#     'organization': {'address': {'city': 'Bath',
#       'country': 'GB',
#       'region': 'Bath and North East Somer'},
#      'disambiguated-organization': {'disambiguated-organization-identifier': '226102',
#       'disambiguation-source': 'RINGGOLD'},
#      'name': 'Eduserv Athens'},
#     'path': '/0000-0003-0902-4386/employment/990539',
#     'put-code': 990539,
#     'role-title': 'Senior Software Engineer',
#     'source': {'source-client-id': None,
#      'source-name': {'value': 'Tom Demeranville'},
#      'source-orcid': {'host': 'orcid.org',
#       'path': '0000-0003-0902-4386',
#       'uri': 'http://orcid.org/0000-0003-0902-4386'}},
#     'start-date': {'day': None,
#      'month': {'value': '01'},
#      'year': {'value': '2005'}},
#     'visibility': 'PUBLIC'},
#    {'created-date': {'value': 1435247923783},
#     'department-name': 'ODIN Project',
#     'end-date': {'day': None,
#      'month': {'value': '12'},
#      'year': {'value': '2014'}},
#     'last-modified-date': {'value': 1435248182295},
#     'organization': {'address': {'city': 'London',
#       'country': 'GB',
#       'region': None},
#      'disambiguated-organization': {'disambiguated-organization-identifier': '4925',
#       'disambiguation-source': 'RINGGOLD'},
#      'name': 'British Library'},
#     'path': '/0000-0003-0902-4386/employment/990536',
#     'put-code': 990536,
#     'role-title': 'Technical Lead',
#     'source': {'source-client-id': None,
#      'source-name': {'value': 'Tom Demeranville'},
#      'source-orcid': {'host': 'orcid.org',
#       'path': '0000-0003-0902-4386',
#       'uri': 'http://orcid.org/0000-0003-0902-4386'}},
#     'start-date': {'day': None,
#      'month': {'value': '02'},
#      'year': {'value': '2013'}},
#     'visibility': 'PUBLIC'},
#    {'created-date': {'value': 1435247860252},
#     'department-name': 'Delivery',
#     'end-date': {'day': None,
#      'month': {'value': '06'},
#      'year': {'value': '2015'}},
#     'last-modified-date': {'value': 1435248181713},
#     'organization': {'address': {'city': 'Bath',
#       'country': 'GB',
#       'region': None},
#      'disambiguated-organization': None,
#      'name': 'IPL'},
#     'path': '/0000-0003-0902-4386/employment/990534',
#     'put-code': 990534,
#     'role-title': 'Technical Lead',
#     'source': {'source-client-id': None,
#      'source-name': {'value': 'Tom Demeranville'},
#      'source-orcid': {'host': 'orcid.org',
#       'path': '0000-0003-0902-4386',
#       'uri': 'http://orcid.org/0000-0003-0902-4386'}},
#     'start-date': {'day': None,
#      'month': {'value': '12'},
#      'year': {'value': '2014'}},
#     'visibility': 'PUBLIC'}],
#   'last-modified-date': {'value': 1442323037800}},
#  'fundings': {'group': [{'external-ids': {'external-id': [{'external-id-relationship': 'SELF',
#        'external-id-type': 'grant_number',
#        'external-id-url': {'value': 'http://cordis.europa.eu/project/rcn/194927_en.html'},
#        'external-id-value': 'H2020-EU.1.4.1.3.'}]},
#     'last-modified-date': {'value': 1474446395681},
#     'summary': [{'created-date': {'value': 1449580576370},
#       'display-index': '0',
#       'end-date': {'day': None,
#        'month': {'value': '11'},
#        'year': {'value': '2017'}},
#       'external-ids': {'external-id': [{'external-id-relationship': 'SELF',
#          'external-id-type': 'grant_number',
#          'external-id-url': {'value': 'http://cordis.europa.eu/project/rcn/194927_en.html'},
#          'external-id-value': 'H2020-EU.1.4.1.3.'}]},
#       'last-modified-date': {'value': 1474446395681},
#       'path': '/0000-0003-0902-4386/funding/133362',
#       'put-code': 133362,
#       'source': {'source-client-id': None,
#        'source-name': {'value': 'Tom Demeranville'},
#        'source-orcid': {'host': 'orcid.org',
#         'path': '0000-0003-0902-4386',
#         'uri': 'http://orcid.org/0000-0003-0902-4386'}},
#       'start-date': {'day': None,
#        'month': {'value': '06'},
#        'year': {'value': '2015'}},
#       'title': {'title': {'value': 'THOR - Technical and Human Infrastructure for Open Research'},
#        'translated-title': None},
#       'type': 'GRANT',
#       'visibility': 'PUBLIC'}]}],
#   'last-modified-date': {'value': 1474446395000}},
#  'last-modified-date': {'value': 1476377063221},
#  'peer-reviews': {'group': [], 'last-modified-date': None},
#  'works': {'group': [{'external-ids': {'external-id': [{'external-id-relationship': 'SELF',
#        'external-id-type': 'doi',
#        'external-id-url': None,
#        'external-id-value': '10.6084/M9.FIGSHARE.1373669'}]},
#     'last-modified-date': {'value': 1461581367720},
#     'work-summary': [{'created-date': {'value': 1435247580221},
#       'display-index': '3',
#       'external-ids': {'external-id': [{'external-id-relationship': 'SELF',
#          'external-id-type': 'doi',
#          'external-id-url': None,
#          'external-id-value': '10.6084/M9.FIGSHARE.1373669'}]},
#       'last-modified-date': {'value': 1461581367719},
#       'path': '/0000-0003-0902-4386/work/17080227',
#       'publication-date': {'day': None,
#        'media-type': None,
#        'month': None,
#        'year': {'value': '2015'}},
#       'put-code': 17080227,
#       'source': {'source-client-id': {'host': 'orcid.org',
#         'path': '0000-0001-8099-6984',
#         'uri': 'http://orcid.org/client/0000-0001-8099-6984'},
#        'source-name': {'value': 'DataCite'},
#        'source-orcid': None},
#       'title': {'subtitle': None,
#        'title': {'value': 'D4.2: Workflow for interoperability'},
#        'translated-title': None},
#       'type': 'DATA_SET',
#       'visibility': 'PUBLIC'},
#      {'created-date': {'value': 1435233269117},
#       'display-index': '1',
#       'external-ids': {'external-id': [{'external-id-relationship': 'SELF',
#          'external-id-type': 'doi',
#          'external-id-url': None,
#          'external-id-value': '10.6084/M9.FIGSHARE.1373669'}]},
#       'last-modified-date': {'value': 1461581367720},
#       'path': '/0000-0003-0902-4386/work/17080287',
#       'publication-date': {'day': None,
#        'media-type': None,
#        'month': None,
#        'year': {'value': '2015'}},
#       'put-code': 17080287,
#       'source': {'source-client-id': None,
#        'source-name': {'value': 'Tom Demeranville'},
#        'source-orcid': {'host': 'orcid.org',
#         'path': '0000-0003-0902-4386',
#         'uri': 'http://orcid.org/0000-0003-0902-4386'}},
#       'title': {'subtitle': None,
#        'title': {'value': 'D4.2: Workflow for interoperability'},
#        'translated-title': None},
#       'type': 'REPORT',
#       'visibility': 'PUBLIC'}]},
#    {'external-ids': {'external-id': [{'external-id-relationship': 'SELF',
#        'external-id-type': 'cit',
#        'external-id-url': None,
#        'external-id-value': 'cite-self'},
#       {'external-id-relationship': 'SELF',
#        'external-id-type': 'agr',
#        'external-id-url': None,
#        'external-id-value': 'pdb-value-self'}]},
#     'last-modified-date': {'value': 1476376312227},
#     'work-summary': [{'created-date': {'value': 1476376312221},
#       'display-index': '1',
#       'external-ids': {'external-id': [{'external-id-relationship': 'SELF',
#          'external-id-type': 'agr',
#          'external-id-url': None,
#          'external-id-value': 'pdb-value-self'},
#         {'external-id-relationship': 'SELF',
#          'external-id-type': 'cit',
#          'external-id-url': None,
#          'external-id-value': 'cite-self'}]},
#       'last-modified-date': {'value': 1476376312227},
#       'path': '/0000-0003-0902-4386/work/27365906',
#       'publication-date': None,
#       'put-code': 27365906,
#       'source': {'source-client-id': None,
#        'source-name': {'value': 'Tom Demeranville'},
#        'source-orcid': {'host': 'orcid.org',
#         'path': '0000-0003-0902-4386',
#         'uri': 'http://orcid.org/0000-0003-0902-4386'}},
#       'title': {'subtitle': None,
#        'title': {'value': 'PDB TEST'},
#        'translated-title': None},
#       'type': 'JOURNAL_ARTICLE',
#       'visibility': 'PUBLIC'}]},
#    {'external-ids': {'external-id': []},
#     'last-modified-date': {'value': 1476377063221},
#     'work-summary': [{'created-date': {'value': 1476377063199},
#       'display-index': '1',
#       'external-ids': {'external-id': [{'external-id-relationship': 'PART_OF',
#          'external-id-type': 'agr',
#          'external-id-url': None,
#          'external-id-value': 'pdb-value-part-of'},
#         {'external-id-relationship': 'PART_OF',
#          'external-id-type': 'cit',
#          'external-id-url': None,
#          'external-id-value': 'cit-part-of'}]},
#       'last-modified-date': {'value': 1476377063221},
#       'path': '/0000-0003-0902-4386/work/27366023',
#       'publication-date': None,
#       'put-code': 27366023,
#       'source': {'source-client-id': None,
#        'source-name': {'value': 'Tom Demeranville'},
#        'source-orcid': {'host': 'orcid.org',
#         'path': '0000-0003-0902-4386',
#         'uri': 'http://orcid.org/0000-0003-0902-4386'}},
#       'title': {'subtitle': None,
#        'title': {'value': 'PDB TEST PART OF'},
#        'translated-title': None},
#       'type': 'JOURNAL_ARTICLE',
#       'visibility': 'PUBLIC'}]},
#    {'external-ids': {'external-id': [{'external-id-relationship': 'SELF',
#        'external-id-type': 'doi',
#        'external-id-url': None,
#        'external-id-value': '10.6084/M9.FIGSHARE.824317'}]},
#     'last-modified-date': {'value': 1461581367719},
#     'work-summary': [{'created-date': {'value': 1439996639727},
#       'display-index': '0',
#       'external-ids': {'external-id': [{'external-id-relationship': 'SELF',
#          'external-id-type': 'doi',
#          'external-id-url': None,
#          'external-id-value': '10.6084/M9.FIGSHARE.824317'}]},
#       'last-modified-date': {'value': 1461581367719},
#       'path': '/0000-0003-0902-4386/work/18003936',
#       'publication-date': {'day': None,
#        'media-type': None,
#        'month': None,
#        'year': {'value': '2013'}},
#       'put-code': 18003936,
#       'source': {'source-client-id': {'host': 'orcid.org',
#         'path': '0000-0001-8099-6984',
#         'uri': 'http://orcid.org/client/0000-0001-8099-6984'},
#        'source-name': {'value': 'DataCite'},
#        'source-orcid': None},
#       'title': {'subtitle': None,
#        'title': {'value': 'D3.1 Humanities and Social Science Proof of Concept'},
#        'translated-title': None},
#       'type': 'DATA_SET',
#       'visibility': 'PUBLIC'}]},
#    {'external-ids': {'external-id': [{'external-id-relationship': 'SELF',
#        'external-id-type': 'doi',
#        'external-id-url': None,
#        'external-id-value': '10.5281/ZENODO.30030'}]},
#     'last-modified-date': {'value': 1461581367720},
#     'work-summary': [{'created-date': {'value': 1443708906024},
#       'display-index': '0',
#       'external-ids': {'external-id': [{'external-id-relationship': 'SELF',
#          'external-id-type': 'doi',
#          'external-id-url': None,
#          'external-id-value': '10.5281/ZENODO.30030'}]},
#       'last-modified-date': {'value': 1461581367720},
#       'path': '/0000-0003-0902-4386/work/18875588',
#       'publication-date': {'day': None,
#        'media-type': None,
#        'month': None,
#        'year': {'value': '2012'}},
#       'put-code': 18875588,
#       'source': {'source-client-id': {'host': 'orcid.org',
#         'path': '0000-0001-8099-6984',
#         'uri': 'http://orcid.org/client/0000-0001-8099-6984'},
#        'source-name': {'value': 'DataCite'},
#        'source-orcid': None},
#       'title': {'subtitle': None,
#        'title': {'value': 'ORCID and DATACITE Interoperability Network (ODIN)'},
#        'translated-title': None},
#       'type': 'OTHER',
#       'visibility': 'PUBLIC'}]},
#    {'external-ids': {'external-id': [{'external-id-relationship': 'SELF',
#        'external-id-type': 'doi',
#        'external-id-url': None,
#        'external-id-value': '10.6084/m9.figshare.1598096'}]},
#     'last-modified-date': {'value': 1461581367720},
#     'work-summary': [{'created-date': {'value': 1447169741596},
#       'display-index': '0',
#       'external-ids': {'external-id': [{'external-id-relationship': 'SELF',
#          'external-id-type': 'doi',
#          'external-id-url': None,
#          'external-id-value': '10.6084/m9.figshare.1598096'}]},
#       'last-modified-date': {'value': 1461581367720},
#       'path': '/0000-0003-0902-4386/work/20140994',
#       'publication-date': {'day': None,
#        'media-type': None,
#        'month': {'value': '11'},
#        'year': {'value': '2015'}},
#       'put-code': 20140994,
#       'source': {'source-client-id': {'host': 'orcid.org',
#         'path': '0000-0001-9892-9368',
#         'uri': 'http://orcid.org/client/0000-0001-9892-9368'},
#        'source-name': {'value': 'figshare ORCID integration'},
#        'source-orcid': None},
#       'title': {'subtitle': None,
#        'title': {'value': 'ORCID and CERIF'},
#        'translated-title': None},
#       'type': 'OTHER',
#       'visibility': 'PUBLIC'}]},
#    {'external-ids': {'external-id': [{'external-id-relationship': 'SELF',
#        'external-id-type': 'doi',
#        'external-id-url': None,
#        'external-id-value': '10.6084/M9.FIGSHARE.1582705.V1'}]},
#     'last-modified-date': {'value': 1461581367720},
#     'work-summary': [{'created-date': {'value': 1459416226538},
#       'display-index': '0',
#       'external-ids': {'external-id': [{'external-id-relationship': 'SELF',
#          'external-id-type': 'doi',
#          'external-id-url': None,
#          'external-id-value': '10.6084/M9.FIGSHARE.1582705.V1'}]},
#       'last-modified-date': {'value': 1461581367720},
#       'path': '/0000-0003-0902-4386/work/23239357',
#       'publication-date': {'day': None,
#        'media-type': None,
#        'month': None,
#        'year': {'value': '2015'}},
#       'put-code': 23239357,
#       'source': {'source-client-id': {'host': 'orcid.org',
#         'path': '0000-0001-8099-6984',
#         'uri': 'http://orcid.org/client/0000-0001-8099-6984'},
#        'source-name': {'value': 'DataCite'},
#        'source-orcid': None},
#       'title': {'subtitle': None,
#        'title': {'value': 'ORCID Public Data File 2015'},
#        'translated-title': None},
#       'type': 'DATA_SET',
#       'visibility': 'PUBLIC'}]},
#    {'external-ids': {'external-id': [{'external-id-relationship': 'SELF',
#        'external-id-type': 'doi',
#        'external-id-url': None,
#        'external-id-value': '10.5281/ZENODO.48228'}]},
#     'last-modified-date': {'value': 1461581367720},
#     'work-summary': [{'created-date': {'value': 1459416226870},
#       'display-index': '0',
#       'external-ids': {'external-id': [{'external-id-relationship': 'SELF',
#          'external-id-type': 'doi',
#          'external-id-url': None,
#          'external-id-value': '10.5281/ZENODO.48228'}]},
#       'last-modified-date': {'value': 1461581367720},
#       'path': '/0000-0003-0902-4386/work/23239358',
#       'publication-date': {'day': None,
#        'media-type': None,
#        'month': None,
#        'year': {'value': '2016'}},
#       'put-code': 23239358,
#       'source': {'source-client-id': {'host': 'orcid.org',
#         'path': '0000-0001-8099-6984',
#         'uri': 'http://orcid.org/client/0000-0001-8099-6984'},
#        'source-name': {'value': 'DataCite'},
#        'source-orcid': None},
#       'title': {'subtitle': None,
#        'title': {'value': 'THOR Communications Plan'},
#        'translated-title': None},
#       'type': 'OTHER',
#       'visibility': 'PUBLIC'}]},
#    {'external-ids': {'external-id': [{'external-id-relationship': 'SELF',
#        'external-id-type': 'doi',
#        'external-id-url': None,
#        'external-id-value': '10.5281/ZENODO.30799'}]},
#     'last-modified-date': {'value': 1461581367720},
#     'work-summary': [{'created-date': {'value': 1459416241937},
#       'display-index': '0',
#       'external-ids': {'external-id': [{'external-id-relationship': 'SELF',
#          'external-id-type': 'doi',
#          'external-id-url': None,
#          'external-id-value': '10.5281/ZENODO.30799'}]},
#       'last-modified-date': {'value': 1461581367720},
#       'path': '/0000-0003-0902-4386/work/23239361',
#       'publication-date': {'day': None,
#        'media-type': None,
#        'month': None,
#        'year': {'value': '2015'}},
#       'put-code': 23239361,
#       'source': {'source-client-id': {'host': 'orcid.org',
#         'path': '0000-0001-8099-6984',
#         'uri': 'http://orcid.org/client/0000-0001-8099-6984'},
#        'source-name': {'value': 'DataCite'},
#        'source-orcid': None},
#       'title': {'subtitle': None,
#        'title': {'value': 'D2.1: Artefact, Contributor, and Organisation Relationship Data Schema'},
#        'translated-title': None},
#       'type': 'OTHER',
#       'visibility': 'PUBLIC'}]},
#    {'external-ids': {'external-id': [{'external-id-relationship': 'SELF',
#        'external-id-type': 'doi',
#        'external-id-url': None,
#        'external-id-value': '10.5281/ZENODO.48705'}]},
#     'last-modified-date': {'value': 1476360642100},
#     'work-summary': [{'created-date': {'value': 1466168070578},
#       'display-index': '0',
#       'external-ids': {'external-id': [{'external-id-relationship': 'SELF',
#          'external-id-type': 'doi',
#          'external-id-url': None,
#          'external-id-value': '10.5281/ZENODO.48705'}]},
#       'last-modified-date': {'value': 1476360642100},
#       'path': '/0000-0003-0902-4386/work/24798864',
#       'publication-date': {'day': None,
#        'media-type': None,
#        'month': None,
#        'year': {'value': '2016'}},
#       'put-code': 24798864,
#       'source': {'source-client-id': {'host': 'orcid.org',
#         'path': '0000-0001-8099-6984',
#         'uri': 'http://orcid.org/client/0000-0001-8099-6984'},
#        'source-name': {'value': 'DataCite'},
#        'source-orcid': None},
#       'title': {'subtitle': None,
#        'title': {'value': 'THOR: Conceptual Model of Persistent Identifier Linking'},
#        'translated-title': None},
#       'type': 'OTHER',
#       'visibility': 'PUBLIC'}]},
#    {'external-ids': {'external-id': [{'external-id-relationship': 'SELF',
#        'external-id-type': 'doi',
#        'external-id-url': None,
#        'external-id-value': '10.5281/ZENODO.46761'}]},
#     'last-modified-date': {'value': 1476360645224},
#     'work-summary': [{'created-date': {'value': 1468427369403},
#       'display-index': '0',
#       'external-ids': {'external-id': [{'external-id-relationship': 'SELF',
#          'external-id-type': 'doi',
#          'external-id-url': None,
#          'external-id-value': '10.5281/ZENODO.46761'}]},
#       'last-modified-date': {'value': 1476360645224},
#       'path': '/0000-0003-0902-4386/work/25382907',
#       'publication-date': {'day': None,
#        'media-type': None,
#        'month': None,
#        'year': {'value': '2016'}},
#       'put-code': 25382907,
#       'source': {'source-client-id': None,
#        'source-name': {'value': 'DataCite'},
#        'source-orcid': {'host': 'orcid.org',
#         'path': '0000-0001-8099-6984',
#         'uri': 'http://orcid.org/0000-0001-8099-6984'}},
#       'title': {'subtitle': None,
#        'title': {'value': 'THOR: Metrics and Tools'},
#        'translated-title': None},
#       'type': 'OTHER',
#       'visibility': 'PUBLIC'}]}],
#   'last-modified-date': {'value': 1476360645000}}}

# %% [markdown]
# Next steps for the SHARE Curation Associates ORCID group:
#
# Access points: do we begin by extracting ORCID IDs from SHARE db and create a loader for pushing selected ORCID data into SHARE?  Or do we try to cast a wider net, say, use an algorithm that attempts to match SHARE personal name strings + institutional affiliations + publications against ORCID data?  And just what data do we push from ORCID into SHARE?  External (researcher)IDs + Researcher IDs?  Affiliation history?  Funding history? That messy, messy publication data?
